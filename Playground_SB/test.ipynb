# %%
import pandas as pd

# %%
data= pd.read_csv('./topified_vectorized_Science_1900_2023_cleaned_up.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                                     title_abstract
# 0           0  Acoustical characteristics tinnitus. analysis....  \
# 1           1  Reproductive steroids bovine. VI. Changes inte...
# 2           2  Aluminium saturation I- S-type granites charac...
# 3           3  Research development agricultural robotics: pe...
# 4           4  Modular representations symmetric groups analy...
#
#   publicationDate  citationCount  influentialCitationCount  topic_code
# 0      1962-02-01             69                         1          20  \
# 1      1971-07-01             51                         0          26
# 2      1999-03-01           1015                       139           0
# 3      2018-08-08            299                         7           0
# 4      1951-11-07             51                         5          19
#
#                              topic_list  x_vector  y_vector  z_vector
# 0  20_hearing_ear_auditory_hearing loss  2.364143  5.038495  3.597319  \
# ...
