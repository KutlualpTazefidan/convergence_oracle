# %%
date_start = "2005-09-01"
date_end = "2022-12-31"
issn = '1476-4687'  #ISSN for Nature

global_api_key = "06653b182ca2ae299e9ce3d3d5d676fd"

# use this link:    https://dev.springernature.com/adding-constraints

#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun May 17 17:24:43 2020
Search in Spring Nature using API by keywords for NIS lab reserch projects.

@author oudeng, Graduate School of Human Sciences, Waseda University

Python program for searching info from Springer Nature via API by XML.
Results includes the title, pdf url and abstract of destination articles. 

https://dev.springernature.com/signup.  
registerred by WasedaID of Ou,DENG, got necessary API.

How to use?
1) Run this program in Python eviroment, including bs4 and requests lib.
2) Input keywords for searching.
3) Searching results will in Python console window.
4) Read in console window directly if not too many results,
   or copy contents to any other more confortable browsers.
5) Copy url of artitle you like in results, use broswer to read PDF.
 
Can use for other API?
Yes. By modifying base_url, api_key, total and content identification tags.
Just confirm the url you try in other API. 

Can for JSON?
No, this programe for XML only.

"""

from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import itertools

# Use a for-loop to flatten a list of lists
def flatten_lists(listToFlatten):
    flat_list = list()
    for sub_list in listToFlatten:
        flat_list += sub_list
    return flat_list

def getXML(url):
    try:
        r = requests.get(url, timeout = 30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return "Scraping Errors. Oooop!!"

def spList(total): 
    S=1 
    P=50
    if total%P != 0:
        s = list(range(S, total//P*P, P)) + [total//P*P+1]
        p = list([P]*(len(s)-1)) + [total%P]
    else:
        s = list(range(S, total//P*P, P)) 
        p = list([P]*len(s))
    # print(s)
    # print(p)
    return s, p

def search_function():
    base_url = "http://api.springernature.com/metadata/pam?q="
    api_key = "&api_key=" + global_api_key
    #Please register at SpringerNature as the following url for your API key.
    # https://www.springernature.com/gp/campaign/librarian-covid-tdm?sap-outbound-id=64AF2B62DCE26C591DAA9263090CDAF763E0CD1F
    
    #input keywords to search in API, url_1 for confirm 'total' value    
    
    date_range = "onlinedatefrom:" + date_start + "%20 onlinedateto:" + date_end
    journalISSN = " issn: " + issn
    
    # ================================================================= change keywords
    #keywords = input("Input '+' in searching keywords:    ")
    # =================================================================
    
    url_1 = base_url + date_range + journalISSN + api_key
    xml_1 = getXML(url_1)
    soup = bs(xml_1,'html.parser')
    total = int(soup.find('total').string)
    
    print('Search Results Totally =',total)
    
    s, p = spList(total)
    
    full_list_of_papers = []
    
    ## you can only download 100 at a time so loop through the download 
    for i in range(len(s)):
    # ================================================================= change keywords
        url = base_url + date_range + journalISSN + '&s=' + str(s[i]) + '&p=' + str(p[i]) + api_key
    # =================================================================
        xml = getXML(url)
        soup = bs(xml, "html.parser")
        current_list_of_papers = soup.find_all('pam:message')
        full_list_of_papers.append(current_list_of_papers)
    
            
    print('Total=',total)
    return flatten_lists(full_list_of_papers)

## pull data 
## get citation number 
#https://stackoverflow.com/questions/69067691/retrieve-number-of-citations-of-a-scientific-paper-in-a-given-year
# pull all the data
# get data from allometric 

def search_to_dataframe(flattened_papers_list):
    all_papers = flattened_papers_list
    first_paper = all_papers[0]
    list_of_fields = list(set([tag.name for tag in first_paper.find_all()]))

    ## create a dictionary with a set of keys that is column titles
    dict_of_paper_fields = {}
    for i in list_of_fields: 
        appenddict = {i:[]}
        dict_of_paper_fields.update(appenddict)

    ## find the fields for each paper
    for i in all_papers: 
        for j in list_of_fields: 
            dict_of_paper_fields[j].append(i.find_all(j))

    return pd.DataFrame(dict_of_paper_fields)

def csv_of_data(dataframeCreated):
    dataframeCreated.to_csv('data/' +"nature"+ "__"+ date_start+"_"+date_end+ '.csv',index=False)

def main():
    list_of_search = search_function()
    dataframe_of_search = search_to_dataframe(list_of_search)
    csv_of_data(dataframe_of_search)

# %%
main()
# Out:
# Search Results Totally = 67518
# Total= 67518

# %%
df = pd.read_csv('data/nature__2005-09-01_2022-12-31.csv')

# %%
df
# Out:
#                                              superscript  \
# 0      [<superscript><citationref additionalcitationi...
# 1      [<superscript><citationref citationid="CR1">1<...
# 2      [<superscript><citationref additionalcitationi...
# 3      [<superscript><citationref additionalcitationi...
# 4      [<superscript><citationref citationid="CR1">1<...
# ...                                                  ...
# 67513                                                 []
# 67514                                                 []
# 67515                                                 []
# 67516                                                 []
# 67517                                                 []
#
#                                 dc:publisher                       journalid  \
# 0      [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
# 1      [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
# 2      [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
# 3      [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
# 4      [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
# ...                                      ...                             ...
# 67513  [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
# 67514  [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
# 67515  [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
# 67516  [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
# 67517  [<dc:publisher>Nature</dc:publisher>]  [<journalid>41586</journalid>]
#
#                                               xhtml:head  \
# 0      [<xhtml:head>\n<pam:article><prism:contenttype...
# 1      [<xhtml:head>\n<pam:article><prism:contenttype...
# 2      [<xhtml:head>\n<pam:article><prism:contenttype...
# 3      [<xhtml:head>\n<pam:article><prism:contenttype...
# 4      [<xhtml:head>\n<pam:article><prism:contenttype...
# ...                                                  ...
# 67513  [<xhtml:head>\n<pam:article><prism:contenttype...
# 67514  [<xhtml:head>\n<pam:article><prism:contenttype...
# 67515  [<xhtml:head>\n<pam:article><prism:contenttype...
# 67516  [<xhtml:head>\n<pam:article><prism:contenttype...
# 67517  [<xhtml:head>\n<pam:article><prism:contenttype...
#
#                               prism:number                        openaccess  \
# 0      [<prism:number>7978</prism:number>]   [<openaccess>true</openaccess>]
# 1      [<prism:number>7962</prism:number>]  [<openaccess>false</openaccess>]
# 2      [<prism:number>7953</prism:number>]   [<openaccess>true</openaccess>]
# 3      [<prism:number>7950</prism:number>]   [<openaccess>true</openaccess>]
# 4      [<prism:number>7950</prism:number>]   [<openaccess>true</openaccess>]
# ...                                    ...                               ...
# 67513      [<prism:number></prism:number>]  [<openaccess>false</openaccess>]
# 67514      [<prism:number></prism:number>]  [<openaccess>false</openaccess>]
# 67515      [<prism:number></prism:number>]  [<openaccess>false</openaccess>]
# 67516  [<prism:number>7055</prism:number>]  [<openaccess>false</openaccess>]
# 67517      [<prism:number></prism:number>]  [<openaccess>false</openaccess>]
#
#                            dc:language  \
# 0      [<dc:language>en</dc:language>]
# 1      [<dc:language>en</dc:language>]
# 2      [<dc:language>en</dc:language>]
# 3      [<dc:language>en</dc:language>]
# 4      [<dc:language>en</dc:language>]
# ...                                ...
# 67513  [<dc:language>en</dc:language>]
# 67514  [<dc:language>en</dc:language>]
# 67515  [<dc:language>en</dc:language>]
# 67516  [<dc:language>en</dc:language>]
# 67517  [<dc:language>en</dc:language>]
#
#                                              prism:genre  \
# 0      [<prism:genre>OriginalPaper</prism:genre>, <pr...
# 1      [<prism:genre>OriginalPaper</prism:genre>, <pr...
# 2      [<prism:genre>OriginalPaper</prism:genre>, <pr...
# 3      [<prism:genre>OriginalPaper</prism:genre>, <pr...
# 4      [<prism:genre>OriginalPaper</prism:genre>, <pr...
# ...                                                  ...
# 67513                  [<prism:genre>News</prism:genre>]
# 67514                  [<prism:genre>News</prism:genre>]
# 67515                  [<prism:genre>News</prism:genre>]
# 67516    [<prism:genre>BriefCommunication</prism:genre>]
# 67517                  [<prism:genre>News</prism:genre>]
#
#                                              citationref  \
# 0      [<citationref additionalcitationids="CR2" cita...
# 1        [<citationref citationid="CR1">1</citationref>]
# 2      [<citationref additionalcitationids="CR2" cita...
# 3      [<citationref additionalcitationids="CR2 CR3 C...
# 4      [<citationref citationid="CR1">1</citationref>...
# ...                                                  ...
# 67513                                                 []
# 67514                                                 []
# 67515                                                 []
# 67516                                                 []
# 67517                                                 []
#
#                                    prism:startingpage  ...  \
# 0      [<prism:startingpage>365</prism:startingpage>]  ...
# 1      [<prism:startingpage>792</prism:startingpage>]  ...
# 2      [<prism:startingpage>687</prism:startingpage>]  ...
# 3      [<prism:startingpage>151</prism:startingpage>]  ...
# 4      [<prism:startingpage>134</prism:startingpage>]  ...
# ...                                               ...  ...
# 67513     [<prism:startingpage></prism:startingpage>]  ...
# 67514     [<prism:startingpage></prism:startingpage>]  ...
# 67515     [<prism:startingpage></prism:startingpage>]  ...
# 67516  [<prism:startingpage>164</prism:startingpage>]  ...
# 67517     [<prism:startingpage></prism:startingpage>]  ...
#
#                                            dc:identifier  \
# 0      [<dc:identifier>doi:10.1038/s41586-022-05279-8...
# 1      [<dc:identifier>doi:10.1038/s41586-022-04967-9...
# 2      [<dc:identifier>doi:10.1038/s41586-022-05531-1...
# 3      [<dc:identifier>doi:10.1038/s41586-022-05628-7...
# 4      [<dc:identifier>doi:10.1038/s41586-022-05594-0...
# ...                                                  ...
# 67513  [<dc:identifier>doi:10.1038/news050829-17</dc:...
# 67514  [<dc:identifier>doi:10.1038/news050829-16</dc:...
# 67515  [<dc:identifier>doi:10.1038/news050829-15</dc:...
# 67516  [<dc:identifier>doi:10.1038/nj7055-164a</dc:id...
# 67517  [<dc:identifier>doi:10.1038/nj0089</dc:identif...
#
#                                                prism:url  \
# 0      [<prism:url>http://dx.doi.org/10.1038/s41586-0...
# 1      [<prism:url>http://dx.doi.org/10.1038/s41586-0...
# 2      [<prism:url>http://dx.doi.org/10.1038/s41586-0...
# 3      [<prism:url>http://dx.doi.org/10.1038/s41586-0...
# 4      [<prism:url>http://dx.doi.org/10.1038/s41586-0...
# ...                                                  ...
# 67513  [<prism:url>http://dx.doi.org/10.1038/news0508...
# 67514  [<prism:url>http://dx.doi.org/10.1038/news0508...
# 67515  [<prism:url>http://dx.doi.org/10.1038/news0508...
# 67516  [<prism:url>http://dx.doi.org/10.1038/nj7055-1...
# 67517  [<prism:url>http://dx.doi.org/10.1038/nj0089</...
#
#                                               dc:subject  \
# 0      [<dc:subject>Science, Humanities and Social Sc...
# 1      [<dc:subject>Science, Humanities and Social Sc...
# 2      [<dc:subject>Science, Humanities and Social Sc...
# 3      [<dc:subject>Science, Humanities and Social Sc...
# 4      [<dc:subject>Science, Humanities and Social Sc...
# ...                                                  ...
# 67513  [<dc:subject>Science, Humanities and Social Sc...
# 67514  [<dc:subject>Science, Humanities and Social Sc...
# 67515  [<dc:subject>Science, Humanities and Social Sc...
# 67516  [<dc:subject>Science, Humanities and Social Sc...
# 67517  [<dc:subject>Science, Humanities and Social Sc...
#
#                                              pam:article  \
# 0      [<pam:article><prism:contenttype>Article</pris...
# 1      [<pam:article><prism:contenttype>Article</pris...
# 2      [<pam:article><prism:contenttype>Article</pris...
# 3      [<pam:article><prism:contenttype>Article</pris...
# 4      [<pam:article><prism:contenttype>Article</pris...
# ...                                                  ...
# 67513  [<pam:article><prism:contenttype>Article</pris...
# 67514  [<pam:article><prism:contenttype>Article</pris...
# 67515  [<pam:article><prism:contenttype>Article</pris...
# 67516  [<pam:article><prism:contenttype>Article</pris...
# 67517  [<pam:article><prism:contenttype>Article</pris...
#
#                                    prism:publicationname  \
# 0      [<prism:publicationname>Nature</prism:publicat...
# 1      [<prism:publicationname>Nature</prism:publicat...
# 2      [<prism:publicationname>Nature</prism:publicat...
# 3      [<prism:publicationname>Nature</prism:publicat...
# 4      [<prism:publicationname>Nature</prism:publicat...
# ...                                                  ...
# 67513  [<prism:publicationname>Nature</prism:publicat...
# 67514  [<prism:publicationname>Nature</prism:publicat...
# 67515  [<prism:publicationname>Nature</prism:publicat...
# 67516  [<prism:publicationname>Nature</prism:publicat...
# 67517  [<prism:publicationname>Nature</prism:publicat...
#
#                                  prism:issn  \
# 0      [<prism:issn>1476-4687</prism:issn>]
# 1      [<prism:issn>1476-4687</prism:issn>]
# 2      [<prism:issn>1476-4687</prism:issn>]
# 3      [<prism:issn>1476-4687</prism:issn>]
# 4      [<prism:issn>1476-4687</prism:issn>]
# ...                                     ...
# 67513  [<prism:issn>1476-4687</prism:issn>]
# 67514  [<prism:issn>1476-4687</prism:issn>]
# 67515  [<prism:issn>1476-4687</prism:issn>]
# 67516  [<prism:issn>1476-4687</prism:issn>]
# 67517  [<prism:issn>1476-4687</prism:issn>]
#
#                                                 dc:title  \
# 0      [<dc:title>Inferring and perturbing cell fate ...
# 1      [<dc:title>Induction of mouse totipotent stem ...
# 2      [<dc:title>Non-viral precision T cell receptor...
# 3      [<dc:title>Active eosinophils regulate host de...
# 4      [<dc:title>FXR inhibition may protect from SAR...
# ...                                                  ...
# 67513  [<dc:title>British duo probes origin of mad co...
# 67514  [<dc:title>Spaghetti filters cleanse water sup...
# 67515      [<dc:title>Aerobot aims for Titan</dc:title>]
# 67516      [<dc:title>Expression of interest</dc:title>]
# 67517           [<dc:title>Highlight: Vienna</dc:title>]
#
#                                          prism:copyright                   h1  \
# 0      [<prism:copyright>©2022 The Author(s)</prism:c...  [<h1>Abstract</h1>]
# 1      [<prism:copyright>©2022 The Author(s), under e...  [<h1>Abstract</h1>]
# 2      [<prism:copyright>©2022 The Author(s)</prism:c...  [<h1>Abstract</h1>]
# 3      [<prism:copyright>©2022 The Author(s)</prism:c...  [<h1>Abstract</h1>]
# 4      [<prism:copyright>©2022 The Author(s)</prism:c...  [<h1>Abstract</h1>]
# ...                                                  ...                  ...
# 67513  [<prism:copyright>©2005 Springer Nature Limite...                   []
# 67514  [<prism:copyright>©2005 Springer Nature Limite...                   []
# 67515  [<prism:copyright>©2005 Springer Nature Limite...                   []
# 67516  [<prism:copyright>©2005 Springer Nature Limite...                   []
# 67517  [<prism:copyright>©2005 Springer Nature Limite...                   []
#
#                                               dc:creator
# 0      [<dc:creator>Fleck, Jonas Simon</dc:creator>, ...
# 1      [<dc:creator>Hu, Yanyan</dc:creator>, <dc:crea...
# 2      [<dc:creator>Foy, Susan P.</dc:creator>, <dc:c...
# 3      [<dc:creator>Gurtner, Alessandra</dc:creator>,...
# 4      [<dc:creator>Brevini, Teresa</dc:creator>, <dc...
# ...                                                  ...
# 67513         [<dc:creator>Khamsi, Roxanne</dc:creator>]
# 67514    [<dc:creator>von Bubnoff, Andreas</dc:creator>]
# 67515            [<dc:creator>Peplow, Mark</dc:creator>]
# 67516            [<dc:creator>Hoag, Hannah</dc:creator>]
# 67517                                                 []
#
# [67518 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['superscript', 'dc:publisher', 'journalid', 'xhtml:head',
#        'prism:number', 'openaccess', 'dc:language', 'prism:genre',
#        'citationref', 'prism:startingpage', 'prism:publicationdate', 'p',
#        'prism:contenttype', 'xhtml:body', 'prism:endingpage', 'prism:volume',
#        'prism:doi', 'dc:identifier', 'prism:url', 'dc:subject', 'pam:article',
#        'prism:publicationname', 'prism:issn', 'dc:title', 'prism:copyright',
#        'h1', 'dc:creator'],
#       dtype='object')

# %%
df['p']
# Out:
# 0        [<p>Self-organizing neural organoids grown fro...
# 1        [<p>In mice, only the zygotes and blastomeres ...
# 2        [<p>T cell receptors (TCRs) enable T cells to ...
# 3        [<p>In the past decade, single-cell transcript...
# 4        [<p>Preventing SARS-CoV-2 infection by modulat...
#                                ...
# 67513    [<p>Did human remains in food spawn the infect...
# 67514    [<p>Chemists package bacteria to eliminate per...
# 67515    [<p>Robotic plane could survey alien moons or ...
# 67516    [<p>Scientists willing to tackle membrane prot...
# 67517                                                   []
# Name: p, Length: 67518, dtype: object

# %%
df['dc:publisher'].unique()
# Out:
# array(['[<dc:publisher>Nature</dc:publisher>]'], dtype=object)

# %%
df_nature = df.copy()
