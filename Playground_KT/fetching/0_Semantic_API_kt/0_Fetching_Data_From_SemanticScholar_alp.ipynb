# %% [markdown]
# # Semantic Scholar API
# 100 requests per 5 minutes
# The API allows up to 100 requests per 5 minutes.
#
# To access a higher rate limit, complete the form to request authentication for your project.
#
# Max limit for each request is 100, so every 5 min we can gather (100*100)* amount of people
#
# Issue/Drawback of semantic scholar: it needs a search term, meaning, the topics/industry/niche needs to be chosen

# %%
import requests
import json
import pandas as pd
import time
import string
import json

# %%
# Parameters for retrieving data
amount_of_data = 100  # Total amount of data to retrieve
start_date = 1900  # Year of publication
end_date = 2023  # Year of publication
journal = ["Science"]
# research_field = ['Computer Science'] # Research field(s) to query (as a list)
alphabet_letters = list(string.ascii_uppercase) # Research field(s) to query (as a list)
initial_offset = 0  # Initial start offset
number_of_publications_per_request = 100

# Gentle fetching
sleep_duration = 5  # Sleep duration in seconds between requests
max_retries = 3  # Maximum number of retries for failed requests

# Define the API endpoint
api_url = 'https://api.semanticscholar.org/graph/v1/paper/search'
length_df = 0

# %%
# Fetching Data
year_list = list(range(start_date, end_date + 1))
year_list.reverse()
for j, year in enumerate(year_list):
    print("Year",year)
    for k,letter in enumerate(alphabet_letters):
        # First request to get the number of total papers to limit the loop
        params = {
            'query': alphabet_letters[k],  # Use the first research field from the list
            'venue': journal[0],
            'year': year,
            'limit': 1,  # Number of results per request
            'offset': 0,  # Offset for pagination
            'fields': 'title,authors,abstract,citationCount,referenceCount,influentialCitationCount,fieldsOfStudy,s2FieldsOfStudy,publicationTypes,publicationDate,embedding.specter_v2,tldr,citations,references,publicationVenue,year',
        }

        # Make the GET request
        response = requests.get(api_url, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            data = json.loads(response.text)

        # calculate the batches required to get every publication for that topic
        num_batches, remainder = divmod(data['total'], number_of_publications_per_request)
        batches = [number_of_publications_per_request] * num_batches
        if remainder > 0:
            batches.append(remainder)
            
        print("For the letter: ", letter ," batches: ",batches)

        for i,batch in enumerate(batches):
            offset = initial_offset + number_of_publications_per_request * i  # Calculate the current offset
            retries = 0

            while retries < max_retries:
                # Define query parameters
                params = {
                    'query': alphabet_letters[k],  # Use the first research field from the list
                    'venue': journal[0],
                    'year': year,
                    'limit': batch,  # Number of results per request
                    'offset': offset,  # Offset for pagination
                    'fields': 'title,authors,abstract,citationCount,year',
                }

                # Make the GET request
                response = requests.get(api_url, params=params)
                # Check if the request was successful
                if response.status_code == 200:
                    data = json.loads(response.text)

                    # Create a DataFrame for unfiltered results
                    df = pd.DataFrame(data['data'])

                    break  # Successful request, exit the retry loop
                else:
                    print(f"Error (Attempt {retries + 1}):", response.status_code)
                    retries += 1
                    if retries < max_retries:
                        print("Retrying after sleep...")
                        time.sleep(sleep_duration)
                    if retries == max_retries:
                        print("Sleeping for 5min")
                        time.sleep(300)
            # print("total amount",response.json())
            length_df += len(df)  # Update the total length of unfiltered data

            # Save each iteration into a separate file - to keep some of the data in case of an error
            # The filename format includes the research field, offset, and is converted to lowercase
            df.to_csv('./data/'+ str(year) +"_"+ journal[0]+"_" + alphabet_letters[k].replace(" ", "_").lower() + "_" + str(offset) + '.csv', index=False)

            # Sleep for a specified duration between requests
            print("Letter", alphabet_letters[k], "Iteration: ", i)
            time.sleep(sleep_duration)

# Print the total length of unfiltered data after all iterations
print("Length of the data", length_df)
# Out:
# Year 2023
# For the letter:  A  batches:  [100, 91]
# Letter A Iteration:  0
# Letter A Iteration:  1
# For the letter:  B  batches:  [100, 3]
# Letter B Iteration:  0
# Letter B Iteration:  1
# For the letter:  C  batches:  [100, 77]
# Letter C Iteration:  0
# Letter C Iteration:  1
# For the letter:  D  batches:  [100, 30]
# Letter D Iteration:  0
# Letter D Iteration:  1
# For the letter:  E  batches:  [100, 36]
# Letter E Iteration:  0
# Letter E Iteration:  1
# For the letter:  F  batches:  [76]
# Letter F Iteration:  0
# For the letter:  G  batches:  [82]
# Letter G Iteration:  0
# For the letter:  H  batches:  [100, 5]
# Letter H Iteration:  0
# Letter H Iteration:  1
# For the letter:  I  batches:  [76]
# Letter I Iteration:  0
# For the letter:  J  batches:  [100, 98]
# Letter J Iteration:  0
# Letter J Iteration:  1
# For the letter:  K  batches:  [92]
# Letter K Iteration:  0
# For the letter:  L  batches:  [100, 34]
# Letter L Iteration:  0
# Letter L Iteration:  1
# For the letter:  M  batches:  [100, 100, 27]
# Letter M Iteration:  0
# Letter M Iteration:  1
# Letter M Iteration:  2
# For the letter:  N  batches:  [100, 10]
# Letter N Iteration:  0
# Letter N Iteration:  1
# For the letter:  O  batches:  [30]
# Letter O Iteration:  0
# For the letter:  P  batches:  [100, 22]
# Letter P Iteration:  0
# Letter P Iteration:  1
# For the letter:  Q  batches:  [14]
# Letter Q Iteration:  0
# For the letter:  R  batches:  [100, 24]
# Letter R Iteration:  0
# Letter R Iteration:  1
# For the letter:  S  batches:  [100, 84]
# Letter S Iteration:  0
# Letter S Iteration:  1
# For the letter:  T  batches:  [100, 12]
# Letter T Iteration:  0
# Letter T Iteration:  1
# For the letter:  U  batches:  [13]
# Letter U Iteration:  0
# For the letter:  V  batches:  [50]
# Letter V Iteration:  0
# For the letter:  W  batches:  [65]
# Letter W Iteration:  0
# For the letter:  X  batches:  [35]
# Letter X Iteration:  0
# For the letter:  Y  batches:  [37]
# Letter Y Iteration:  0
# For the letter:  Z  batches:  [14]
# Letter Z Iteration:  0
# Year 2022
# For the letter:  A  batches:  [100, 100, 50]
# Letter A Iteration:  0
# Letter A Iteration:  1
# Letter A Iteration:  2
# For the letter:  B  batches:  [100, 82]
# Letter B Iteration:  0
# Letter B Iteration:  1
# For the letter:  C  batches:  [100, 100, 53]
# Letter C Iteration:  0
# Letter C Iteration:  1
# Letter C Iteration:  2
# For the letter:  D  batches:  [100, 100, 36]
# Letter D Iteration:  0
# Letter D Iteration:  1
# Letter D Iteration:  2
# For the letter:  E  batches:  [100, 100, 20]
# Letter E Iteration:  0
# Letter E Iteration:  1
# Letter E Iteration:  2
# For the letter:  F  batches:  [100, 59]
# Letter F Iteration:  0
# Letter F Iteration:  1
# For the letter:  G  batches:  [100, 67]
# Letter G Iteration:  0
# Letter G Iteration:  1
# For the letter:  H  batches:  [100, 92]
# Letter H Iteration:  0
# Letter H Iteration:  1
# For the letter:  I  batches:  [100, 38]
# Letter I Iteration:  0
# Letter I Iteration:  1
# For the letter:  J  batches:  [100, 100, 52]
# Letter J Iteration:  0
# Letter J Iteration:  1
# Letter J Iteration:  2
# For the letter:  K  batches:  [100, 92]
# Letter K Iteration:  0
# Letter K Iteration:  1
# For the letter:  L  batches:  [100, 100, 38]
# Letter L Iteration:  0
# Letter L Iteration:  1
# Letter L Iteration:  2
# For the letter:  M  batches:  [100, 100, 51]
# Letter M Iteration:  0
# Letter M Iteration:  1
# Letter M Iteration:  2
# For the letter:  N  batches:  [100, 67]
# Letter N Iteration:  0
# Letter N Iteration:  1
# For the letter:  O  batches:  [57]
# Letter O Iteration:  0
# For the letter:  P  batches:  [100, 100, 6]
# Letter P Iteration:  0
# Letter P Iteration:  1
# Letter P Iteration:  2
# For the letter:  Q  batches:  [14]
# Letter Q Iteration:  0
# For the letter:  R  batches:  [100, 100, 15]
# Letter R Iteration:  0
# Letter R Iteration:  1
# Letter R Iteration:  2
# For the letter:  S  batches:  [100, 100, 51]
# Letter S Iteration:  0
# Letter S Iteration:  1
# Letter S Iteration:  2
# For the letter:  T  batches:  [100, 86]
# Letter T Iteration:  0
# Letter T Iteration:  1
# For the letter:  U  batches:  [17]
# Letter U Iteration:  0
# For the letter:  V  batches:  [100, 17]
# Letter V Iteration:  0
# Letter V Iteration:  1
# For the letter:  W  batches:  [100, 30]
# Letter W Iteration:  0
# Letter W Iteration:  1
# For the letter:  X  batches:  [59]
# Letter X Iteration:  0
# For the letter:  Y  batches:  [77]
# Letter Y Iteration:  0
# For the letter:  Z  batches:  [28]
# Letter Z Iteration:  0
# Year 2021
# For the letter:  A  batches:  [100, 100, 50]
# Letter A Iteration:  0
# Letter A Iteration:  1
# Letter A Iteration:  2
# For the letter:  B  batches:  [100, 100, 46]
# Letter B Iteration:  0
# Letter B Iteration:  1
# Letter B Iteration:  2
# For the letter:  C  batches:  [100, 100, 100, 3]
# Letter C Iteration:  0
# Letter C Iteration:  1
# Letter C Iteration:  2
# Letter C Iteration:  3
# For the letter:  D  batches:  [100, 100, 52]
# Letter D Iteration:  0
# Letter D Iteration:  1
# Letter D Iteration:  2
# For the letter:  E  batches:  [100, 100, 51]
# Letter E Iteration:  0
# Letter E Iteration:  1
# Letter E Iteration:  2
# For the letter:  F  batches:  [100, 73]
# Letter F Iteration:  0
# Letter F Iteration:  1
# For the letter:  G  batches:  [100, 90]
# Letter G Iteration:  0
# Letter G Iteration:  1
# For the letter:  H  batches:  [100, 100, 34]
# Letter H Iteration:  0
# Letter H Iteration:  1
# Letter H Iteration:  2
# For the letter:  I  batches:  [100, 33]
# Letter I Iteration:  0
# Letter I Iteration:  1
# For the letter:  J  batches:  [100, 100, 66]
# Letter J Iteration:  0
# Letter J Iteration:  1
# Letter J Iteration:  2
# For the letter:  K  batches:  [100, 100, 50]
# Letter K Iteration:  0
# Letter K Iteration:  1
# Letter K Iteration:  2
# For the letter:  L  batches:  [100, 100, 50]
# Letter L Iteration:  0
# Letter L Iteration:  1
# Letter L Iteration:  2
# For the letter:  M  batches:  [100, 100, 68]
# Letter M Iteration:  0
# Letter M Iteration:  1
# Letter M Iteration:  2
# For the letter:  N  batches:  [100, 96]
# Letter N Iteration:  0
# Letter N Iteration:  1
# For the letter:  O  batches:  [64]
# Letter O Iteration:  0
# For the letter:  P  batches:  [100, 100, 100, 100, 100, 100, 63]
# Letter P Iteration:  0
# Letter P Iteration:  1
# Letter P Iteration:  2
# Letter P Iteration:  3
# Letter P Iteration:  4
# Letter P Iteration:  5
# Letter P Iteration:  6
# For the letter:  Q  batches:  [20]
# Letter Q Iteration:  0
# For the letter:  R  batches:  [100, 100, 51]
# Letter R Iteration:  0
# Letter R Iteration:  1
# Letter R Iteration:  2
# For the letter:  S  batches:  [100, 100, 83]
# Letter S Iteration:  0
# Letter S Iteration:  1
# Letter S Iteration:  2
# For the letter:  T  batches:  [100, 100, 50]
# Letter T Iteration:  0
# Letter T Iteration:  1
# Letter T Iteration:  2
# For the letter:  U  batches:  [25]
# Letter U Iteration:  0
# For the letter:  V  batches:  [100, 24]
# Letter V Iteration:  0
# Letter V Iteration:  1
# For the letter:  W  batches:  [100, 49]
# Letter W Iteration:  0
# Letter W Iteration:  1
# For the letter:  X  batches:  [75]
# Letter X Iteration:  0
# For the letter:  Y  batches:  [83]
# Letter Y Iteration:  0
# For the letter:  Z  batches:  [42]
# Letter Z Iteration:  0
# Year 2020
# For the letter:  A  batches:  [100, 100, 50]
# Letter A Iteration:  0
# Letter A Iteration:  1
# Letter A Iteration:  2
# For the letter:  B  batches:  [100, 100, 46]
# Letter B Iteration:  0
# Letter B Iteration:  1
# Letter B Iteration:  2
# For the letter:  C  batches:  [100, 100, 100, 27]
# Letter C Iteration:  0
# Letter C Iteration:  1
# Letter C Iteration:  2
# Letter C Iteration:  3
# For the letter:  D  batches:  [100, 100, 82]
# Letter D Iteration:  0
# Letter D Iteration:  1
# Letter D Iteration:  2
# For the letter:  E  batches:  [100, 100, 76]
# Letter E Iteration:  0
# Letter E Iteration:  1
# Letter E Iteration:  2
# For the letter:  F  batches:  [100, 100, 19]
# Letter F Iteration:  0
# Letter F Iteration:  1
# Letter F Iteration:  2
# For the letter:  G  batches:  [100, 100, 21]
# Letter G Iteration:  0
# Letter G Iteration:  1
# Letter G Iteration:  2
# For the letter:  H  batches:  [100, 100, 53]
# Letter H Iteration:  0
# Letter H Iteration:  1
# Letter H Iteration:  2
# For the letter:  I  batches:  [100, 100, 15]
# Letter I Iteration:  0
# Letter I Iteration:  1
# Letter I Iteration:  2
# For the letter:  J  batches:  [100, 100, 88]
# Letter J Iteration:  0
# Letter J Iteration:  1
# Letter J Iteration:  2
# For the letter:  K  batches:  [100, 100, 52]
# Letter K Iteration:  0
# Letter K Iteration:  1
# Letter K Iteration:  2
# For the letter:  L  batches:  [100, 100, 61]
# Letter L Iteration:  0
# Letter L Iteration:  1
# Letter L Iteration:  2
# For the letter:  M  batches:  [100, 100, 75]
# Letter M Iteration:  0
# Letter M Iteration:  1
# Letter M Iteration:  2
# For the letter:  N  batches:  [100, 100, 1]
# Letter N Iteration:  0
# Letter N Iteration:  1
# Letter N Iteration:  2
# For the letter:  O  batches:  [68]
# Letter O Iteration:  0
# For the letter:  P  batches:  [100, 100, 100, 100, 100, 100, 100, 100, 100]
# Letter P Iteration:  0
# Letter P Iteration:  1
# Letter P Iteration:  2
# Letter P Iteration:  3
# Letter P Iteration:  4
# Letter P Iteration:  5
# Letter P Iteration:  6
# Letter P Iteration:  7
# Letter P Iteration:  8
# For the letter:  Q  batches:  [100, 100, 100, 100, 100, 100, 100, 100, 99]
# Letter Q Iteration:  0
# Error (Attempt 1): 400
# Retrying after sleep...
# Error (Attempt 2): 400
# Retrying after sleep...
# Error (Attempt 3): 400
# Letter Q Iteration:  1
# Error (Attempt 1): 400
# Retrying after sleep...
# Error (Attempt 2): 400
# Retrying after sleep...
# Error (Attempt 3): 400
# Letter Q Iteration:  2
# Error (Attempt 1): 400
# Retrying after sleep...
# Error (Attempt 2): 400
# Retrying after sleep...
# Error (Attempt 3): 400
# Letter Q Iteration:  3
# Error (Attempt 1): 400
# Retrying after sleep...
# Error (Attempt 2): 400
# Retrying after sleep...
# Error (Attempt 3): 400
# Letter Q Iteration:  4
# Error (Attempt 1): 400
# Retrying after sleep...
# Error (Attempt 2): 429
# Retrying after sleep...
# Error (Attempt 3): 400
# Letter Q Iteration:  5
# Error (Attempt 1): 429
# Retrying after sleep...
# Error (Attempt 2): 400
# Retrying after sleep...
# Error (Attempt 3): 400
# Letter Q Iteration:  6
# Error (Attempt 1): 400
# Retrying after sleep...
# Error (Attempt 2): 400
# Retrying after sleep...
# Error (Attempt 3): 400
# Letter Q Iteration:  7
# Error (Attempt 1): 429
# Retrying after sleep...
# Error (Attempt 2): 429
# Retrying after sleep...
# Error (Attempt 3): 400
# Letter Q Iteration:  8
# For the letter:  R  batches:  [100, 100, 72]
# Letter R Iteration:  0
# Letter R Iteration:  1
# Letter R Iteration:  2
# For the letter:  S  batches:  [100, 100, 72]
# Letter S Iteration:  0
# Letter S Iteration:  1
# Letter S Iteration:  2
# For the letter:  T  batches:  [100, 100, 55]
# Error (Attempt 1): 429
# Retrying after sleep...
# Letter T Iteration:  0
# Letter T Iteration:  1
# Error (Attempt 1): 429
# Retrying after sleep...
# Error (Attempt 2): 429
# Retrying after sleep...
# Letter T Iteration:  2
# For the letter:  U  batches:  [31]
# Error (Attempt 1): 429
# Retrying after sleep...
# Letter U Iteration:  0
# For the letter:  V  batches:  [100, 18]
# Letter V Iteration:  0
# Letter V Iteration:  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/linuxuser/spiced-academy/data_science_capstone/convergence_oracle/Playground_KT/fetching/0_Semantic_API_kt/0_Fetching_Data_From_SemanticScholar_alp.ipynb Cell 4 line 7
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/linuxuser/spiced-academy/data_science_capstone/convergence_oracle/Playground_KT/fetching/0_Semantic_API_kt/0_Fetching_Data_From_SemanticScholar_alp.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=69'>70</a>             # Sleep for a specified duration between requests
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/linuxuser/spiced-academy/data_science_capstone/convergence_oracle/Playground_KT/fetching/0_Semantic_API_kt/0_Fetching_Data_From_SemanticScholar_alp.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=70'>71</a>             print("Letter", alphabet_letters[k], "Iteration: ", i)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/linuxuser/spiced-academy/data_science_capstone/convergence_oracle/Playground_KT/fetching/0_Semantic_API_kt/0_Fetching_Data_From_SemanticScholar_alp.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=71'>72</a>             time.sleep(sleep_duration)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/linuxuser/spiced-academy/data_science_capstone/convergence_oracle/Playground_KT/fetching/0_Semantic_API_kt/0_Fetching_Data_From_SemanticScholar_alp.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=73'>74</a> # Print the total length of unfiltered data after all iterations
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/linuxuser/spiced-academy/data_science_capstone/convergence_oracle/Playground_KT/fetching/0_Semantic_API_kt/0_Fetching_Data_From_SemanticScholar_alp.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=74'>75</a> print("Length of the data", length_df)
#
# KeyboardInterrupt:

# %%
df.head().T
# Out:
#                                                                0
# paperId                 5db4916130c2001927bbaccd5a3afb3872d8e6ac  \
# title          Authors’ 2015 additions to the IOC consensus s...
# abstract       In April 2014, the International Olympic Commi...
# year                                                        2015
# citationCount                                                 59
# authors        [{'authorId': '3888843', 'name': 'M. Mountjoy'...
#
#                                                                1
# paperId                 765fc7d33627119d652113e6d065d047f8f6f9bf  \
# title          High Order Exponential Integrators for Nonline...
# abstract       This article deals with the numerical integrat...
# year                                                        2015
# citationCount                                                 31
# authors        [{'authorId': '1869826', 'name': 'C. Besse'}, ...
#
#                                                                2
# paperId                 fc975f2cf0473cdffeef8a8093f61e212f8edf6d  \
# title          Classification of 4-dimensional homogeneous we...
# abstract                                                    None
# year                                                        2015
# citationCount                                                 15
# authors        [{'authorId': '1405423205', 'name': 'T. Arias-...
#
#                                                                3
# paperId                 fc5e34c8d420cc464beb769eab57cf6baabb11af  \
# title          Marginal and Irrelevant Disorder in Einstein-M...
# abstract       A. M. G. thanks Hong Liu and Elias Kiritsis fo...
# year                                                        2015
# citationCount                                                 13
# authors        [{'authorId': '1397392420', 'name': 'Antonio M...
#
#                                                                4
# paperId                 a4d4027465ecdae907ed897d733609e0f49cd980
# title          Five-parameter class of solutions to the vacuu...
# abstract       We present a new five-parameter class of Ricci...
# year                                                        2015
# citationCount                                                 11
# authors        [{'authorId': '2144838481', 'name': 'Yu Chen'}...

# %% [markdown]
# # Single Query - Using the Batch Endpoint

# %%
api_url = 'https://api.semanticscholar.org/graph/v1/paper/search'

# %% [markdown]
# # Rest of the code is not required but it provides example how to filter the data before saving

# %%
# # Fetching and filtering at the same time if required
# # Fetching Data
# length_filtered_df = 0
# length_unfiltered_df = 0

# for i in range(int(amount_of_data/100)):
#     offset = initial_offset + 100 * i
#     retries = 0
    
#     while retries < max_retries:
#         # Define query parameters
#         params = {
#             'query': research_field,
#             'year': year_of_publication,
#             'limit': 100,
#             'offset': offset,
#             'fields': 'title,authors,abstract,citationCount,year',
#         }

#         # Make the GET request
#         response = requests.get(api_url, params=params)

#         # Check if the request was successful
#         if response.status_code == 200:
#             data = json.loads(response.text)

#             # Create a DataFrame for unfiltered results
#             df_unfiltered = pd.DataFrame(data['data'])

#             # Filter the results based on 'citationCount' > 10
#             filtered_results = [paper for paper in data['data'] if paper.get('citationCount', 0) > 10]

#             # Create a DataFrame for filtered results
#             df_filtered = pd.DataFrame(filtered_results)


#             break  # Successful request, exit the retry loop
#         else:
#             print(f"Error (Attempt {retries + 1}):", response.status_code)
#             retries += 1
#             if retries < max_retries:
#                 print("Retrying after sleep...")
#                 time.sleep(sleep_duration)
    
#     # length_filtered_df = len(df_filtered)
#     length_unfiltered_df += len(df_unfiltered)

#     # Save each iteration into separate file - to keep some of the data in case of an error
#     df_unfiltered.to_csv('./data/'+research_field.replace(" ","_").lower() + "_" + str(offset) + '.csv', index=False)
#     df_filtered.to_csv('./data/df_filtered' + str(offset) + '.csv', index=False)

#     # Sleep for a specified duration between requests
#     print("Research field",research_field,"Iteration: ", i)
#     time.sleep(sleep_duration)
# print("Length of the filtered data",length_unfiltered_df)
# print("Length of the unfiltered data",length_filtered_df)

# %%
# https://api.semanticscholar.org/graph/v1/paper/search?query=computer+science&year=2015&fields=title,year,authors,citationCount&limit=50
