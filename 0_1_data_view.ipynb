# %%
import pandas as pd

pd.read_csv(r'C:\Users\erick\gitrepositories\convergence_oracle\data\1552-4450__2005-09-01_2022-12-31.csv')
# Out:
#                                   prism:publicationname
# 0     [<prism:publicationname>Nature Chemical Biolog...  \
# 1     [<prism:publicationname>Nature Chemical Biolog...
# 2     [<prism:publicationname>Nature Chemical Biolog...
# 3     [<prism:publicationname>Nature Chemical Biolog...
# 4     [<prism:publicationname>Nature Chemical Biolog...
# ...                                                 ...
# 3679  [<prism:publicationname>Nature Chemical Biolog...
# 3680  [<prism:publicationname>Nature Chemical Biolog...
# 3681  [<prism:publicationname>Nature Chemical Biolog...
# 3682  [<prism:publicationname>Nature Chemical Biolog...
# 3683  [<prism:publicationname>Nature Chemical Biolog...
#
#                                                dc:title
# 0     [<dc:title>Deep dive into a drug pump</dc:title>]  \
# 1              [<dc:title>A change of phase</dc:title>]
# 2     [<dc:title>Peptides hit the catalysis walk</dc...
# 3     [<dc:title>Ligand recognition and allosteric m...
# ...
