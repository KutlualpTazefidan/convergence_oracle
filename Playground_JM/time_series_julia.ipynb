# %%
 
import pandas as pd
'''
Science1900_2023 = pd.read_csv('/Users/admin/Desktop/spiced/convergence_oracle_repos/convergence_oracle/CodeBase/Science1900_2023.csv')  
topic_proba_data_Science1900_2023 = pd.read_csv('/Users/admin/Desktop/spiced/convergence_oracle_repos/convergence_oracle/CodeBase/topic_proba_data_Science1900_2023.csv')  
topified_vectorized_Science1900_2023 = pd.read_csv('/Users/admin/Desktop/spiced/convergence_oracle_repos/convergence_oracle/CodeBase/topified_vectorized_Science1900_2023.csv')  

'''

# %%
topified_vectorized_Science1900_2023.head(5)
# Out:
#    Unnamed: 0                                   paperId
# 0           0  479c07e8f4537f6cc9cdf740f2037b63735a96ad  \
# 1           1  157afb079051ca47b710f7cdaebfde3e2294e5ca
# 2           2  5774d000143759165e760ba52e64e83e6883a525
# 3           3  d8d6d6eaab5966762ac5c6b3a87f683bfd17474f
# 4           4  2b0d90af12f959b29fed9afefe90f54b4e0324cd
#
#                                          externalIds
# 0  {'MAG': '2066851951', 'DOI': '10.1001/ARCHOTOL...  \
# 1  {'MAG': '2469680164', 'DOI': '10.2527/JAS1971....
# 2  {'MAG': '2511119900', 'DOI': '10.5153/sro.4071...
# 3  {'MAG': '2061837047', 'DOI': '10.1016/S0024-49...
# 4  {'MAG': '2885121946', 'DOI': '10.25165/J.IJABE...
#
#                                     publicationVenue
# 0  {'id': 'a3a6c306-5d4a-48fd-9054-2cd9277bf956',...  \
# 1  {'id': 'bade12e5-f20e-4b51-83a6-534e3705569a',...
# 2                                                NaN
# 3                                                NaN
# ...

# %%
topified_vectorized_Science1900_2023 = topified_vectorized_Science1900_2023.drop(['paperId','externalIds', 'publicationVenue', 'publicationTypes'], axis=1)

# %%
topified_vectorized_Science1900_2023.head(5)
# Out:
#    Unnamed: 0                                              title
# 0           0  Acoustical characteristics of tinnitus. An ana...  \
# 1           1  Reproductive steroids in the bovine. VI. Chang...
# 2           2  Holiday Rentals: The New Gentrification Battle...
# 3           3  Aluminium saturation in I- and S-type granites...
# 4           4  Research and development in agricultural robot...
#
#                                             abstract  year  referenceCount
# 0  The recognition of tinnitus aurium as a proble...  1962               5  \
# 1  Summary Urine and blood samples were collected...  1971              23
# 2  In this paper, I explore the impacts of holida...  2016              24
# 3                                                NaN  1999              26
# 4  Digital farming is the practice of modern tech...  2018             198
#
#    citationCount  influentialCitationCount         fieldsOfStudy
# ...
