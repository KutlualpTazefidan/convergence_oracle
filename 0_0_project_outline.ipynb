# %% [markdown]
# STEP 1
# Build our Raw Data
#
#
#     - Each persons chooses an API
#         - ALP - MICROSOFT SEARCH
#         - JULIA -
#         - DON
#         - ERIC - Springer Nature
#
# Web scraping to pull journal info, abstract, data into csv file
#
#         - Scrape everything and order data
#
# ---------------- BY EOD TUESDAY 19th SEPTEMBER -----------------------------
#
# group coding
#
#         1. connecting queries
#
#         - Through software engineering connect the queries of 4 apis
#
#             - agree upon variable to include during scrapping
#
#                 - eg data, citation, niche, subject + more...
#
#         2. connecting data
#
#         - Connect the 4 data pulls into one database/datalake/dataframe
#
#         - Lets agree on data to connect (filter the feature from each query)
#             - Title
#             - Abstract
#             - Citations
#             - more....
#
# (DATALAKE IS CREATED)
#
# Push full dataset into SQL server on AWS (NEXT WEEK) -- run code on docker
#
# ---------------- BY EOD WEDNESDAY 20th SEPTEMBER -----------------------------
#
# ON CLOUD BERGTOPIC:
#
#     Apply NLP to title + abstract to extract topics
#         -
#
#     Merge data from NLP with web scraping data
#         -
#
# Push full dataset into SQL server on AWS (NEXT WEEK) -- run code on docker
#
#
# ---------------- BY EOD FRIDAY 20th SEPTEMBER -----------------------------
#
#
# STEP 2 ---
#
# Decide on main topics/query + use the framework from above
#
# MOONBOARD: Decide upon list of questions (add below):
#
#     - predictive model for number of citations?
#     - is a topic hot?
#     - is a paper revolutionary?
#     - where is a topic on the inflection?
#     - how to relate to industry?
#     - giving recommendations on how to imprvoe papers, or research?
#
#
#
#
# Create Oracle for Convergence Theory for each of the questions above
#
#
#
#
# 1 WEEK TO PREPARE PRESENTATION FROM BEACH IN FRANCE
#
#
# When we want to achieve what? And timeframe?
