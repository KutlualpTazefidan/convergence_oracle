# %%
from custom_functions import bertopic_addons as cfc

## def localSQL_to_awsSQL(table_name):
test_df = cfc.localSQL_to_awsSQL('Science1900_2023')
# Out:
# Step 1/7: Loading the dataset ...
# Step 2/7: Cleaning the dataset ...
# Dropping 0 duplicates out of 53833 data points.
# Dropping 0 NaNs out of 53833 data points.
# Cleaned df size 53833; Original df size: 53833
# Step 3/7: Creating the analysis column ...
# Step 4/7: Removing stopwords ...
# Step 5/7: We longer drop columns, its not needed ...

# %%
cfc.pull_aws_sql_database('Science1900_2023')
# Out:
# Step 1/7: Loading the dataset ...
#                                         paperId
# 0      e871a051678d851b0b3aff77c41a5054c4b9d194  \
# 1      d846dfece7c01d05454bf2a1e333883e4455df81
# 2      0eadfc8ce07c470c670eeb59905fbdb3b068eca5
# 3      f65897bb6119077fbd60d7c2b718567e74914176
# 4      18138d89800d961e7ad086d97ecbc31b94f82b9c
# ...                                         ...
# 53828  69070cb91fb8adb9e5fa16fa7bbda096adb44246
# 53829  3bfeae61289a4f5ecc41a47f214b9bf314195118
# 53830  1b0acfcaa1074a0295a68a9d5c8b362eae5acf9d
# 53831  f4f49c5eb38cac9aab04bcd2a81c8f3cacf494f9
# 53832  2b55436a465f33bd45e9255240f1b2b76ab755e9
#
#                                              externalIds
# 0      {'MAG': '2064013918', 'DOI': '10.2307/2220775'...  \
# 1      {'MAG': '1553230769', 'DOI': '10.1042/BJ113029...
# 2      {'MAG': '2189135005', 'DOI': '10.1128/iai.57.3...
# 3      {'MAG': '2139620037', 'PubMedCentral': '219294...
# 4      {'MAG': '2107419249', 'DOI': '10.4319/LO.1958....
# ...                                                  ...
# 53828  {'DOI': '10.1038/131678a0', 'CorpusId': 26516174}
# 53829  {'MAG': '1995026967', 'DOI': '10.1046/j.1360-2...
# 53830  {'MAG': '2105284042', 'DOI': '10.1002/pfi.4140...
# 53831  {'MAG': '2194689184', 'CorpusId': 45036940, 'P...
# 53832  {'MAG': '2410230644', 'PubMedCentral': '219140...
#
#                                         publicationVenue
# 0                                                   None  \
# 1      {'id': '64838252-a209-4424-a778-3b86b4a83c48',...
# 2      {'id': '57307fe3-fa8c-47ec-9b5d-4bab7fd699fc',...
# 3      {'id': '7d071626-1aa2-4dad-a259-bcccedccf44d',...
# 4                                                   None
# ...                                                  ...
# 53828  {'id': '6c24a0a0-b07d-4d7b-a19b-fd09a3ed453a',...
# 53829  {'id': '64f545d6-1fc1-4c60-974a-36a504738277',...
# 53830                                               None
# 53831  {'id': '25140240-c27e-483b-92d6-12f261d5a28d',...
# 53832  {'id': '7d071626-1aa2-4dad-a259-bcccedccf44d',...
#
#                                                    title
# 0          The social possibilities of economic chivalry  \
# 1      An enzymic method for the trace iodination of ...
# 2      DNA probes specific for Entamoeba histolytica ...
# 3      Maturation, Activation, and Protection of Dend...
# 4      Benthic Studies in Buzzards Bay. I. Animal‐Sed...
# ...                                                  ...
# 53828          The Royal Entomological Society of London
# 53829  Short communication: Prevalence of Entamoeba h...
# 53830  E-Learning: Strategies for Delivering Knowledg...
# 53831  Postoperative pain; its use in the comparative...
# 53832  Human gene MAGE-3 codes for an antigen recogni...
#
#                                                 abstract  year referenceCount
# 0                                                   None  1907              0  \
# 1      1. A method is described for the trace iodinat...  1969              0
# 2      A number of DNA probes which hybridize to high...  1989             21
# 3      The initiation of an immune response is critic...  1999             44
# 4      During October and November 1955 a bottom faun...  1958             18
# ...                                                  ...   ...            ...
# 53828                                               None  1933              0
# 53829  Since the redescription of the potentially inv...  2003             18
# 53830  From the Publisher: \nIt isn't just the promis...  2000              1
# 53831                                               None  1952              0
# 53832  Human melanoma cell line MZ2-MEL expresses sev...  1994             42
#
#       citationCount influentialCitationCount              fieldsOfStudy
# 0               101                        2              ['Economics']  \
# 1              1225                       11  ['Chemistry', 'Medicine']
# 2               116                        3    ['Biology', 'Medicine']
# 3               836                       45    ['Medicine', 'Biology']
# 4               520                       14                ['Geology']
# ...             ...                      ...                        ...
# 53828           216                       20                       None
# 53829           133                       11    ['Biology', 'Medicine']
# 53830           909                       27       ['Computer Science']
# 53831            97                        4               ['Medicine']
# 53832           815                       26    ['Biology', 'Medicine']
#
#                                          s2FieldsOfStudy
# 0      [{'category': 'Economics', 'source': 'external...  \
# 1      [{'category': 'Chemistry', 'source': 'external...
# 2      [{'category': 'Biology', 'source': 'external'}...
# 3      [{'category': 'Medicine', 'source': 'external'...
# 4      [{'category': 'Geology', 'source': 'external'}...
# ...                                                  ...
# 53828  [{'category': 'History', 'source': 's2-fos-mod...
# 53829  [{'category': 'Biology', 'source': 'external'}...
# 53830  [{'category': 'Computer Science', 'source': 'e...
# 53831  [{'category': 'Medicine', 'source': 'external'...
# 53832  [{'category': 'Biology', 'source': 'external'}...
#
#                             publicationTypes publicationDate
# 0                                       None      1907-03-01  \
# 1                         ['JournalArticle']      1969-06-01
# 2                         ['JournalArticle']      1989-03-01
# 3                         ['JournalArticle']      1999-03-01
# 4                                       None      1958-07-01
# ...                                      ...             ...
# 53828                                   None            None
# 53829  ['Study', 'JournalArticle', 'Review']      2003-12-01
# 53830                                   None      2000-11-16
# 53831                     ['JournalArticle']      1952-07-01
# 53832                     ['JournalArticle']      1994-03-01
#
#                                           title_abstract
# 0                 social possibilities economic chivalry
# 1      enzymic method trace iodination immunoglobulin...
# 2      DNA probes specific Entamoeba histolytica poss...
# 3      Maturation, Activation, Protection Dendritic C...
# 4      Benthic Studies Buzzards Bay. I. Animal‐Sedime...
# ...                                                  ...
# 53828                 Royal Entomological Society London
# 53829  Short communication: Prevalence Entamoeba hist...
# 53830  E-Learning: Strategies Delivering Knowledge Di...
# 53831  Postoperative pain; use comparative evaluation...
# 53832  Human gene MAGE-3 codes antigen recognized mel...
#
# [53833 rows x 14 columns]
