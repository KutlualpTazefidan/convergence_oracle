# %%
from custom_functions import bertopic_addons as cfc

## def localSQL_to_awsSQL(table_name):
test_df = cfc.localSQL_to_awsSQL('Science1900_2023')
# Out:
# Step 1/7: Loading the dataset ...
# Step 2/7: Cleaning the dataset ...
# Dropping 0 duplicates out of 53833 data points.
# Dropping 0 NaNs out of 53833 data points.
# Cleaned df size 53833; Original df size: 53833
# Step 3/7: Creating the analysis column ...
# Step 4/7: Removing stopwords ...
# Step 5/7: We longer drop columns, its not needed ...

# %%
from custom_functions import bertopic_addons as cfc

# %%
import pandas as pd

# %%
df
# Out:
#                                           title_abstract publicationDate  \
# 0      Acoustical characteristics tinnitus. analysis....      1962-02-01
# 1      Reproductive steroids bovine. VI. Changes inte...      1971-07-01
# 2      Aluminium saturation I- S-type granites charac...      1999-03-01
# 3      Research development agricultural robotics: pe...      2018-08-08
# 4      Modular representations symmetric groups analy...      1951-11-07
# ...                                                  ...             ...
# 28951  comparison rate control rhythm control patient...      2002-12-05
# 28952  Type IFNs enhance terminal differentiation den...      1998-08-15
# 28953                        Internal Constitution Stars      1920-09-02
# 28954  PROTOPLASTS L-TYPE GROWTH ESCHERICHIA COLI pre...      1958-02-01
# 28955                  Mean Square Successive Difference      1941-06-01
#
#        citationCount  influentialCitationCount  topic_code  \
# ...

# %%
df = pd.read_csv('topified_vectorized_Science_1900_2023_cleaned_up.csv')

# %%
cfc.dataframe_to_aws_sql(df,'topified_vectorized_Science_1900_2023_cleaned_up')

# %%
cfc.pull_aws_sql_database('topified_vectorized_Science_1900_2023_cleaned_up')
# Out:
# Step 1/7: Loading the dataset ...
#                                           title_abstract publicationDate  \
# 0      Acoustical characteristics tinnitus. analysis....      1962-02-01
# 1      Reproductive steroids bovine. VI. Changes inte...      1971-07-01
# 2      Aluminium saturation I- S-type granites charac...      1999-03-01
# 3      Research development agricultural robotics: pe...      2018-08-08
# 4      Modular representations symmetric groups analy...      1951-11-07
# ...                                                  ...             ...
# 28951  comparison rate control rhythm control patient...      2002-12-05
# 28952  Type IFNs enhance terminal differentiation den...      1998-08-15
# 28953                        Internal Constitution Stars      1920-09-02
# 28954  PROTOPLASTS L-TYPE GROWTH ESCHERICHIA COLI pre...      1958-02-01
# 28955                  Mean Square Successive Difference      1941-06-01
#
# ...
